# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\dell\Desktop\used_cars_data.csv")

# %%
data
# Out:
#       id       brand     model  price (eur)  \
# 0      0        SEAT     Ibiza         8990
# 1      1     Hyundai       i30         9990
# 2      2         BMW   Serie 5        13490
# 3      3  Volkswagen      Golf        24990
# 4      4        Opel     Corsa        10460
# ..   ...         ...       ...          ...
# 787  787  Volkswagen      Golf        13990
# 788  788         Kia  Sportage        24990
# 789  789      Abarth       500        17990
# 790  790  Volkswagen    Tiguan        14990
# 791  791       Dacia    Dokker        14390
#
#                                        engine  year  mileage (kms)      fuel  \
# 0                       SC 1.2 TSI 90cv Style  2016          67000  Gasolina
# 1                        1.6 CRDi 110cv Tecno  2014         104868    Diésel
# 2                                530d Touring  2011         137566    Diésel
# 3                   GTI 2.0 TSI 169kW (230CV)  2018          44495  Gasolina
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             792 non-null    int64
#  1   brand          792 non-null    object
#  2   model          792 non-null    object
#  3   price (eur)    792 non-null    int64
#  4   engine         792 non-null    object
#  5   year           792 non-null    int64
#  6   mileage (kms)  792 non-null    int64
#  7   fuel           792 non-null    object
#  8   gearbox        792 non-null    object
#  9   location       792 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 62.0+ KB

# %%
data.mean()
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_14672/531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# id                 395.500000
# price (eur)      15973.383838
# year              2016.404040
# mileage (kms)    83228.833333
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_14672/4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# id                 395.5
# price (eur)      14990.0
# year              2017.0
# mileage (kms)    80065.5
# dtype: float64

# %%
data.describe()
# Out:
#                id   price (eur)         year  mileage (kms)
# count  792.000000    792.000000   792.000000     792.000000
# mean   395.500000  15973.383838  2016.404040   83228.833333
# std    228.774999   6984.338370     2.452251   46202.118589
# min      0.000000   4990.000000  2004.000000    1258.000000
# 25%    197.750000  11355.000000  2015.000000   47145.500000
# 50%    395.500000  14990.000000  2017.000000   80065.500000
# 75%    593.250000  18490.000000  2018.000000  116321.750000
# max    791.000000  82580.000000  2021.000000  220000.000000

# %%
data.head()
# Out:
#    id       brand    model  price (eur)                     engine  year  \
# 0   0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style  2016
# 1   1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno  2014
# 2   2         BMW  Serie 5        13490               530d Touring  2011
# 3   3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)  2018
# 4   4        Opel    Corsa        10460       1.4 Expression 90 CV  2016
#
#    mileage (kms)      fuel     gearbox    location
# 0          67000  Gasolina      Manual  Granollers
# 1         104868    Diésel      Manual  Viladecans
# 2         137566    Diésel  Automatica  Viladecans
# 3          44495  Gasolina      Manual  Viladecans
# 4          69800  Gasolina      Manual  Sabadell 1

# %%
data.isnull().count()
# Out:
# id               792
# brand            792
# model            792
# price (eur)      792
# engine           792
# year             792
# mileage (kms)    792
# fuel             792
# gearbox          792
# location         792
# dtype: int64

# %%
data["fuel"].unique()
# Out:
# array(['Gasolina', 'Diésel', 'Híbrido', 'GLP', 'Eléctrico'], dtype=object)

# %%
data["gearbox"].unique()
# Out:
# array(['Manual', 'Automatica'], dtype=object)

# %%
sns.countplot(x=data["fuel"],data=data)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %%
sns.countplot(x=data["gearbox"],data=data)
# Out:
# <AxesSubplot:xlabel='gearbox', ylabel='count'>

# %%
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
print(data['price (eur)'].unique())
# Out:
# [ 8990  9990 13490 24990 10460  8490 23990 14990 19490 21990 25490 14490
#  17990 12990 18490 15990 10490 12880 16820  9950 14980 11380 13990 12490
#  57990 16490 18990 11490 17490 20990 15490 18960 18890 14970 10570 27990
#   7990 30490 11990 26990  5990 14790 22990 16990 24490  9490 19990 33990
#  15770  7670 10260 10370 10120 13290 18330 14430 10150 11430 10680 10990
#  17730 11970 25990 22490 15880 13270 15290 11280 16980 12350 10980 20490
#  21430 29950 24410 10930 14470 16210 16250 48990  6990 28380 25330 10880
#  21490  8680  7490 28990  9290 41990 39990  8210 29990 58990 34990 30990
#  19970 11180 23490 23460 13580 14480 82580 31990 18970 36990 33860 19590
#  18780 11790 17360 17290 34490 14590 28490 32490 16710  8790 38490 13470
#  17180 24790 32990  8290 21790 10520 10770 20970 28650 12290 12220 49990
#  14780 17850 16280 13790 10290  6490 26840  7790 31490 16290 16690  7780
#  11750 22790 12950  4990  6760  8980 35990 23960 17890 16540  6690 11880
# ...

# %%
data.boxplot(column =['price (eur)'], grid = True)
# Out:
# <AxesSubplot:>

# %%
q1 = data['price (eur)'].quantile(0.25)
q3 = data['price (eur)'].quantile(0.75)
iqr = q3-q1

upper_limit = q3+1.5*iqr
upper_limit
# Out:
# 29192.5

# %%
data['price (eur)']=np.where(data['price (eur)']>upper_limit,upper_limit,data['price (eur)'])

# %%
data.boxplot(column =['price (eur)'], grid = True)
# Out:
# <AxesSubplot:>

# %%
from sklearn import preprocessing

# %%
label_encoding=preprocessing.LabelEncoder()

# %%
data['fuel1']= label_encoding.fit_transform(data['fuel'])
data['gearbox1']= label_encoding.fit_transform(data['gearbox'])

# %%
data['fuel1'].unique()
# Out:
# array([3, 0, 4, 2, 1])

# %%
data['gearbox1'].unique()
# Out:
# array([1, 0])

# %%
sns.countplot(x=data["gearbox1"],data=data)
# Out:
# <AxesSubplot:xlabel='gearbox1', ylabel='count'>

# %% [markdown]
# # Type of Gearbox

# %% [markdown]
# 0=Automatica,
# 1=Manual

# %%
sns.countplot(x=data["fuel1"],data=data)
# Out:
# <AxesSubplot:xlabel='fuel1', ylabel='count'>

# %% [markdown]
# # Type of Fuel

# %% [markdown]
# 0=Diésel,
# 1=Eléctrico,
# 2=GLP,
# 3=Gasolina,
# 4=Híbrido

# %%
data.corr()
# Out:
#                      id  price (eur)      year  mileage (kms)     fuel1  \
# id             1.000000    -0.034298 -0.112403       0.046866 -0.013148
# price (eur)   -0.034298     1.000000  0.428715      -0.217166 -0.039339
# year          -0.112403     0.428715  1.000000      -0.642867  0.369231
# mileage (kms)  0.046866    -0.217166 -0.642867       1.000000 -0.485983
# fuel1         -0.013148    -0.039339  0.369231      -0.485983  1.000000
# gearbox1      -0.037164    -0.531936 -0.020192      -0.123000  0.086997
#
#                gearbox1
# id            -0.037164
# price (eur)   -0.531936
# year          -0.020192
# mileage (kms) -0.123000
# fuel1          0.086997
# gearbox1       1.000000

# %%
sns.heatmap(data.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#       id       brand     model  price (eur)  \
# 0      0        SEAT     Ibiza       8990.0
# 1      1     Hyundai       i30       9990.0
# 2      2         BMW   Serie 5      13490.0
# 3      3  Volkswagen      Golf      24990.0
# 4      4        Opel     Corsa      10460.0
# ..   ...         ...       ...          ...
# 787  787  Volkswagen      Golf      13990.0
# 788  788         Kia  Sportage      24990.0
# 789  789      Abarth       500      17990.0
# 790  790  Volkswagen    Tiguan      14990.0
# 791  791       Dacia    Dokker      14390.0
#
#                                        engine  year  mileage (kms)      fuel  \
# 0                       SC 1.2 TSI 90cv Style  2016          67000  Gasolina
# 1                        1.6 CRDi 110cv Tecno  2014         104868    Diésel
# 2                                530d Touring  2011         137566    Diésel
# 3                   GTI 2.0 TSI 169kW (230CV)  2018          44495  Gasolina
# ...

# %% [markdown]
# # spitt the data into two part

# %%
x=data.iloc[:,[6,10,11]]

# %%
y=data.iloc[:,3]

# %%
x
# Out:
#      mileage (kms)  fuel1  gearbox1
# 0            67000      3         1
# 1           104868      0         1
# 2           137566      0         0
# 3            44495      3         1
# 4            69800      3         1
# ..             ...    ...       ...
# 787          84040      0         1
# 788          65872      3         1
# 789          28830      3         1
# 790         162895      0         0
# 791           9800      0         1
#
# [792 rows x 3 columns]

# %%
y
# Out:
# 0       8990.0
# 1       9990.0
# 2      13490.0
# 3      24990.0
# 4      10460.0
#         ...
# 787    13990.0
# 788    24990.0
# 789    17990.0
# 790    14990.0
# 791    14390.0
# Name: price (eur), Length: 792, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
# Plot the training data and the regression line
plt.scatter(x_train.iloc[:, 0], y_train, label='Training Data')
plt.scatter(x_test.iloc[:, 0], y_test, color='red', label='Test Data')
plt.plot(x_test.iloc[:, 0], y_pred, color='blue', linewidth=3, label='Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Example')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2 = r2_score(y_test, y_pred)

# %%
print(f'R^2 Score: {r2}')
# Out:
# R^2 Score: 0.3691165755487532

# %%
r_2 = model.score(x_test, y_test)

# %%
print(f'R^2 Score: {r_2}')
# Out:
# R^2 Score: 0.3691165755487532

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 19623599.29210042
